# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#from HashML.Clustering import *
#from HashML.Util import ecludian_distance,Normalized_dataframe #,fit,accuracy_value
import scipy as sp
import networkx as nx
from HashML.decomposition import *
# from HashML.Gradient import *

# %%
df = pd.read_csv('data/Diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
feature=df.iloc[:,:8]
feature
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
fig = plt.figure(figsize=(10,10))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
new_feautres=PCA(df.drop('Outcome',axis=1),2)
# Out:
# singular values are:  [3212.6611207   845.82919167  547.33280231  389.87962763  293.9941346
#   187.48648707   77.15221185    8.88268374]

# %%
new_feautres
# Out:
#             A0         A1
# 0   -75.714655 -35.950783
# 1   -82.358268  28.908213
# 2   -74.630643 -67.906496
# 3    11.077423  34.898486
# 4    89.743788  -2.746937
# ..         ...        ...
# 763  99.237881  25.080927
# 764 -78.641239  -7.688010
# 765  32.113198   3.376665
# 766 -80.214494 -14.186020
# 767 -81.308150  21.621496
#
# [768 rows x 2 columns]

# %%
plt.figure(figsize=(10,10))
plt.scatter(x=new_feautres.iloc[:,0],y=new_feautres.iloc[:,1],c=df['Outcome'],cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
fig = plt.figure(figsize=(10,10))
sns.heatmap(new_feautres.corr())
# Out:
# <Axes: >
